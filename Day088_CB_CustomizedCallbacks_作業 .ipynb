# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative
#
# ![image.png](attachment:image.png)

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[256, 256, 256]):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import Callback
# Record_fp_tp
class Record_tp_tn(Callback):
    """Code Here
    撰寫一個紀錄 ture positive 與 true negative 數量的 callbacks    
    """
    def __init__ (self, validation_data):
        self.validation_data = validation_data
        
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = ["val_auc", "val_f1sc", "val_fp", "val_fn", "val_tp", "val_tn"]
        for i in record_items:
            if i not in logs.keys():
                    logs[i] = []
                    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        val_tp = sum(y_true*y_pred)
        val_tn = sum((y_true==0) & (y_pred==0))
        
        logs["val_tp"] = val_tp
        logs["val_tn"] = val_tn
    
        
rec_tptn = Record_tp_tn((x_test, y_test))

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(learning_rate=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

"""Code Here
將 callbacks 放入模型訓練流程中
"""
model.fit(x_train, y_train,epochs=EPOCHS,batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test),shuffle=True,
          callbacks=[rec_tptn])

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""
valid_tp = model.history.history["val_tp"]
valid_tn = model.history.history["val_tn"]
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_layer1 (Dense)           │ (None, 256)            │       786,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_layer2 (Dense)           │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_layer3 (Dense)           │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 923,914 (3.52 MB)
#  Trainable params: 922,378 (3.52 MB)
#  Non-trainable params: 1,536 (6.00 KB)
# Epoch 1/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step  accuracy: 0.1881 -
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.1953 - loss: 2.5202 - val_accuracy: 0.1822 - val_loss: 2.1611 - val_tp: 0.0000e+00 - val_tn: 1000.0000
# Epoch 2/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/stepaccuracy: 0.3711 - l
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.3719 - loss: 1.8110 - val_accuracy: 0.2685 - val_loss: 2.0151 - val_tp: 1.0000 - val_tn: 1000.0000
# Epoch 3/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/stepaccuracy: 0.4190 - los
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.4196 - loss: 1.6600 - val_accuracy: 0.3446 - val_loss: 1.8643 - val_tp: 1.0000 - val_tn: 1000.0000
# Epoch 4/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/stepaccuracy: 0.4459 - l
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.4461 - loss: 1.5760 - val_accuracy: 0.4043 - val_loss: 1.7302 - val_tp: 90.0000 - val_tn: 1000.0000
# Epoch 5/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/stepaccuracy: 0.4689 - los
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.4689 - loss: 1.5151 - val_accuracy: 0.4259 - val_loss: 1.6421 - val_tp: 265.0000 - val_tn: 1000.0000
# Epoch 6/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/stepaccuracy: 0.4837 - l
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.4841 - loss: 1.4792 - val_accuracy: 0.4451 - val_loss: 1.5853 - val_tp: 473.0000 - val_tn: 999.0000
# Epoch 7/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/stepaccuracy: 0.4997 - los
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.4997 - loss: 1.4290 - val_accuracy: 0.4538 - val_loss: 1.5461 - val_tp: 1090.0000 - val_tn: 998.0000
# Epoch 8/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/stepaccuracy: 0.5073 - l
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5074 - loss: 1.4074 - val_accuracy: 0.4648 - val_loss: 1.5274 - val_tp: 1019.0000 - val_tn: 995.0000
# Epoch 9/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/stepaccuracy: 0.5206 - los
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5207 - loss: 1.3734 - val_accuracy: 0.4610 - val_loss: 1.5165 - val_tp: 1167.0000 - val_tn: 995.0000
# Epoch 10/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/stepaccuracy: 0.5345 - l
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5342 - loss: 1.3426 - val_accuracy: 0.4724 - val_loss: 1.4988 - val_tp: 1226.0000 - val_tn: 996.0000
# Epoch 11/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/stepaccuracy: 0.5443 - l
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5443 - loss: 1.3162 - val_accuracy: 0.4759 - val_loss: 1.4925 - val_tp: 1260.0000 - val_tn: 996.0000
# Epoch 12/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/stepaccuracy: 0.5505 - l
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5505 - loss: 1.2992 - val_accuracy: 0.4766 - val_loss: 1.4835 - val_tp: 2550.0000 - val_tn: 989.0000
# Epoch 13/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/stepaccuracy: 0.5574 - l
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5577 - loss: 1.2791 - val_accuracy: 0.4829 - val_loss: 1.4702 - val_tp: 1627.0000 - val_tn: 993.0000
# Epoch 14/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/stepaccuracy: 0.5680 - l
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5681 - loss: 1.2493 - val_accuracy: 0.4772 - val_loss: 1.4741 - val_tp: 1216.0000 - val_tn: 996.0000
# Epoch 15/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/stepaccuracy: 0.5753 - los
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5754 - loss: 1.2355 - val_accuracy: 0.4828 - val_loss: 1.4679 - val_tp: 2246.0000 - val_tn: 992.0000
# Epoch 16/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/stepaccuracy: 0.5872 - l
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5871 - loss: 1.2057 - val_accuracy: 0.4883 - val_loss: 1.4604 - val_tp: 1638.0000 - val_tn: 996.0000
# Epoch 17/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/stepaccuracy: 0.5922 - los
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5922 - loss: 1.1827 - val_accuracy: 0.4867 - val_loss: 1.4535 - val_tp: 2032.0000 - val_tn: 993.0000
# Epoch 18/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/stepaccuracy: 0.5964 - lo
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5967 - loss: 1.1736 - val_accuracy: 0.4932 - val_loss: 1.4594 - val_tp: 2123.0000 - val_tn: 988.0000
# Epoch 19/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/stepaccuracy: 0.6064 - l
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6064 - loss: 1.1497 - val_accuracy: 0.4837 - val_loss: 1.4545 - val_tp: 2432.0000 - val_tn: 989.0000
# Epoch 20/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/stepaccuracy: 0.6141 - l
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6140 - loss: 1.1308 - val_accuracy: 0.4933 - val_loss: 1.4519 - val_tp: 2225.0000 - val_tn: 987.0000
# Epoch 21/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/stepaccuracy: 0.6194 - l
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6193 - loss: 1.1117 - val_accuracy: 0.4896 - val_loss: 1.4500 - val_tp: 1956.0000 - val_tn: 992.0000
# Epoch 22/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/stepaccuracy: 0.6258 - l
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6258 - loss: 1.0953 - val_accuracy: 0.4924 - val_loss: 1.4513 - val_tp: 2049.0000 - val_tn: 987.0000
# Epoch 23/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/stepaccuracy: 0.6322 - l
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6322 - loss: 1.0841 - val_accuracy: 0.4960 - val_loss: 1.4503 - val_tp: 2606.0000 - val_tn: 986.0000
# Epoch 24/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/stepaccuracy: 0.6427 - los
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6422 - loss: 1.0521 - val_accuracy: 0.4950 - val_loss: 1.4623 - val_tp: 1906.0000 - val_tn: 988.0000
# Epoch 25/25
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/stepaccuracy: 0.6474 - l
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.6472 - loss: 1.0431 - val_accuracy: 0.4992 - val_loss: 1.4402 - val_tp: 1899.0000 - val_tn: 987.0000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
