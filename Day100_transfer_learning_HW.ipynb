# %% [markdown]
# ## 作業
# 礙於不是所有同學都有 GPU ，這邊的範例使用的是簡化版本的 ResNet，確保所有同學都能夠順利訓練!
#
#
# 最後一天的作業請閱讀這篇非常詳盡的[文章](https://blog.gtwang.org/programming/keras-resnet-50-pre-trained-model-build-dogs-cats-image-classification-system/)，基本上已經涵蓋了所有訓練　CNN 常用的技巧，請使用所有學過的訓練技巧，盡可能地提高 Cifar-10 的 test data 準確率，截圖你最佳的結果並上傳來完成最後一次的作業吧!
#
# 另外這些技巧在 Kaggle 上也會被許多人使用，更有人會開發一些新的技巧，例如使把預訓練在 ImageNet 上的模型當成 feature extractor 後，再拿擷取出的特徵重新訓練新的模型，這些技巧再進階的課程我們會在提到，有興趣的同學也可以[參考](https://www.kaggle.com/insaff/img-feature-extraction-with-pretrained-resnet)

# %%
import keras
from keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau

batch_size = 128
num_classes = 10
epochs = 50  # 增加 epochs

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

# 調整後的資料增強
data_generator = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# 學習率衰減回調
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=0.00001)

# 開始訓練
history = model.fit(data_generator.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=int(len(x_train) / batch_size),
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test),
                    callbacks=[reduce_lr])

# 測試模型
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/50
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 15s 36ms/step - accuracy: 0.2717 - loss: 1.9435 - val_accuracy: 0.5042 - val_loss: 1.3649 - learning_rate: 0.0010
# Epoch 2/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4688 - loss: 1.4748 - val_accuracy: 0.4889 - val_loss: 1.4000 - learning_rate: 0.0010
# Epoch 3/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.4740 - loss: 1.4414 - val_accuracy: 0.5781 - val_loss: 1.1729 - learning_rate: 0.0010
# Epoch 4/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5547 - loss: 1.2341 - val_accuracy: 0.5797 - val_loss: 1.1812 - learning_rate: 0.0010
# Epoch 5/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.5532 - loss: 1.2497 - val_accuracy: 0.6325 - val_loss: 1.0249 - learning_rate: 0.0010
# Epoch 6/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5703 - loss: 1.2348 - val_accuracy: 0.6295 - val_loss: 1.0345 - learning_rate: 0.0010
# Epoch 7/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.5981 - loss: 1.1260 - val_accuracy: 0.6708 - val_loss: 0.9387 - learning_rate: 0.0010
# Epoch 8/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5859 - loss: 1.1888 - val_accuracy: 0.6713 - val_loss: 0.9421 - learning_rate: 0.0010
# Epoch 9/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - accuracy: 0.6247 - loss: 1.0588 - val_accuracy: 0.6964 - val_loss: 0.8606 - learning_rate: 0.0010
# Epoch 10/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6953 - loss: 0.9863 - val_accuracy: 0.6982 - val_loss: 0.8571 - learning_rate: 0.0010
# Epoch 11/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.6474 - loss: 1.0064 - val_accuracy: 0.7007 - val_loss: 0.8509 - learning_rate: 0.0010
# Epoch 12/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6484 - loss: 1.0594 - val_accuracy: 0.7099 - val_loss: 0.8327 - learning_rate: 0.0010
# Epoch 13/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.6602 - loss: 0.9622 - val_accuracy: 0.7245 - val_loss: 0.7816 - learning_rate: 0.0010
# Epoch 14/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6719 - loss: 0.9022 - val_accuracy: 0.7249 - val_loss: 0.7751 - learning_rate: 0.0010
# Epoch 15/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.6779 - loss: 0.9230 - val_accuracy: 0.7105 - val_loss: 0.8183 - learning_rate: 0.0010
# Epoch 16/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6562 - loss: 0.8921 - val_accuracy: 0.7118 - val_loss: 0.8093 - learning_rate: 0.0010
# Epoch 17/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.6882 - loss: 0.8977 - val_accuracy: 0.7445 - val_loss: 0.7214 - learning_rate: 0.0010
# Epoch 18/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7344 - loss: 0.7893 - val_accuracy: 0.7443 - val_loss: 0.7289 - learning_rate: 0.0010
# Epoch 19/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.6914 - loss: 0.8728 - val_accuracy: 0.7456 - val_loss: 0.7190 - learning_rate: 0.0010
# Epoch 20/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7109 - loss: 0.8922 - val_accuracy: 0.7461 - val_loss: 0.7177 - learning_rate: 0.0010
# Epoch 21/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.7002 - loss: 0.8522 - val_accuracy: 0.7115 - val_loss: 0.8415 - learning_rate: 0.0010
# Epoch 22/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7969 - loss: 0.7763 - val_accuracy: 0.7073 - val_loss: 0.8604 - learning_rate: 0.0010
# Epoch 23/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.7104 - loss: 0.8333 - val_accuracy: 0.7462 - val_loss: 0.7279 - learning_rate: 0.0010
# Epoch 24/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7344 - loss: 0.8039 - val_accuracy: 0.7513 - val_loss: 0.7179 - learning_rate: 5.0000e-04
# Epoch 25/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.7259 - loss: 0.7830 - val_accuracy: 0.7587 - val_loss: 0.6959 - learning_rate: 5.0000e-04
# Epoch 26/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7109 - loss: 0.7416 - val_accuracy: 0.7594 - val_loss: 0.6915 - learning_rate: 5.0000e-04
# Epoch 27/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.7282 - loss: 0.7829 - val_accuracy: 0.7611 - val_loss: 0.6790 - learning_rate: 5.0000e-04
# Epoch 28/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7656 - loss: 0.7016 - val_accuracy: 0.7598 - val_loss: 0.6828 - learning_rate: 5.0000e-04
# Epoch 29/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.7364 - loss: 0.7582 - val_accuracy: 0.7702 - val_loss: 0.6565 - learning_rate: 5.0000e-04
# Epoch 30/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7188 - loss: 0.6801 - val_accuracy: 0.7714 - val_loss: 0.6524 - learning_rate: 5.0000e-04
# Epoch 31/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.7387 - loss: 0.7444 - val_accuracy: 0.7674 - val_loss: 0.6800 - learning_rate: 5.0000e-04
# Epoch 32/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6875 - loss: 0.9182 - val_accuracy: 0.7599 - val_loss: 0.7002 - learning_rate: 5.0000e-04
# Epoch 33/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.7409 - loss: 0.7385 - val_accuracy: 0.7775 - val_loss: 0.6457 - learning_rate: 5.0000e-04
# Epoch 34/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7500 - loss: 0.8648 - val_accuracy: 0.7798 - val_loss: 0.6426 - learning_rate: 5.0000e-04
# Epoch 35/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.7471 - loss: 0.7254 - val_accuracy: 0.7756 - val_loss: 0.6527 - learning_rate: 5.0000e-04
# Epoch 36/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6406 - loss: 0.9818 - val_accuracy: 0.7733 - val_loss: 0.6570 - learning_rate: 5.0000e-04
# Epoch 37/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.7476 - loss: 0.7228 - val_accuracy: 0.7760 - val_loss: 0.6455 - learning_rate: 5.0000e-04
# Epoch 38/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6797 - loss: 0.8909 - val_accuracy: 0.7777 - val_loss: 0.6423 - learning_rate: 2.5000e-04
# Epoch 39/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.7487 - loss: 0.6987 - val_accuracy: 0.7779 - val_loss: 0.6509 - learning_rate: 2.5000e-04
# Epoch 40/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8125 - loss: 0.6375 - val_accuracy: 0.7779 - val_loss: 0.6510 - learning_rate: 2.5000e-04
# Epoch 41/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.7601 - loss: 0.6926 - val_accuracy: 0.7814 - val_loss: 0.6427 - learning_rate: 2.5000e-04
# Epoch 42/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7500 - loss: 0.7107 - val_accuracy: 0.7825 - val_loss: 0.6395 - learning_rate: 1.2500e-04
# Epoch 43/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.7622 - loss: 0.6796 - val_accuracy: 0.7919 - val_loss: 0.6058 - learning_rate: 1.2500e-04
# Epoch 44/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7500 - loss: 0.6652 - val_accuracy: 0.7914 - val_loss: 0.6059 - learning_rate: 1.2500e-04
# Epoch 45/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.7610 - loss: 0.6763 - val_accuracy: 0.7792 - val_loss: 0.6471 - learning_rate: 1.2500e-04
# Epoch 46/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7656 - loss: 0.6633 - val_accuracy: 0.7798 - val_loss: 0.6437 - learning_rate: 1.2500e-04
# Epoch 47/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.7702 - loss: 0.6605 - val_accuracy: 0.7918 - val_loss: 0.6042 - learning_rate: 6.2500e-05
# Epoch 48/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7344 - loss: 0.6556 - val_accuracy: 0.7919 - val_loss: 0.6031 - learning_rate: 6.2500e-05
# Epoch 49/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.7678 - loss: 0.6588 - val_accuracy: 0.7831 - val_loss: 0.6333 - learning_rate: 6.2500e-05
# Epoch 50/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8438 - loss: 0.4481 - val_accuracy: 0.7821 - val_loss: 0.6344 - learning_rate: 6.2500e-05
# Test loss: 0.6344419717788696
# Test accuracy: 0.7821000218391418
